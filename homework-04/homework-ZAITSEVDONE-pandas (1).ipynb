# %% [markdown]
# # Библиотека PANDAS
# ### !!!Пожалуйста, подпишите своё задание - напишите в заголовке ФИО и номер группы

# %%
Зайцев Никита Кириллович НММ-Бд-01-22

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В каждом разделе вам предлагается выполнить несколько заданий. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотекам pandas и matplotlib.
#
# ### Оценивание и штрафы
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написаем production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.
#
# ### Формат сдачи
# Для сдачи задания получившийся файл \*.ipynb с решением необходимо выложить в свой репозиторий github.

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных. С этой библиотекой мы сейчас и познакомимся.
#
# Основной объект в pandas это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# !pip3 install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 667.8 kB/s eta 0:00:18
#     --------------------------------------- 0.2/11.6 MB 2.4 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/11.6 MB 4.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.6 MB 4.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.6 MB 6.8 MB/s eta 0:00:02
#    ------------- -------------------------- 3.9/11.6 MB 13.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.8/11.6 MB 23.8 MB/s eta 0:00:01
#    --------------------------- ------------ 8.1/11.6 MB 24.7 MB/s eta 0:00:01
#    --------------------------- ------------ 8.1/11.6 MB 24.7 MB/s eta 0:00:01
#    --------------------------- ------------ 8.1/11.6 MB 24.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.1/11.6 MB 16.8 MB/s eta 0:00:01
# ...

# %%
# %pylab inline  
# import almost all we need
import pandas as pd
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Данные находятся в приложенном файле `chipotle.tsv`

# %% [markdown]
# #### 1. Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы?

# %%
import pandas as pd

# Загрузка данных из файла chipotle.tsv
df = pd.read_csv('chipotle.tsv', sep='\t')

# Вывод последних 10 строк таблицы
print(df.tail(10))
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
Всего в таблице 4621 строк и 5 столбца order_id  quantity  item_name choice_description item_price

# %% [markdown]
# #### 2.  Ответьте на вопросы:
# 1. Сколько заказов попало в выборку?
# 2. Сколько уникальных категорий товара было куплено? (item_name)

# %%
# Подсчет количества заказов
num_orders = df['order_id'].nunique()

# Подсчет количества уникальных категорий товара
num_unique_items = df['item_name'].nunique()

print( num_orders)
print(num_unique_items)
# Out:
# 1834
# 50

# %%
Количество заказов в выборке 1834 , а уникальных товаров 50 .я воспользовался методом nunique чтобы определить количество чисел(без их поторения)

# %% [markdown]
# #### 3. Есть ли в данных пропуски? В каких колонках?

# %%
# Проверка наличия пропусков в данных и определение колонок с пропусками
missing_values = df.isnull().sum()

# Вывод количества пропусков по каждой колонке
print("\nПропуски в данных:")
print(missing_values)
# Out:
# Пропуски в данных:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
Только в колонке choice_description

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
# Заполнение пропусков пустой строкой для строковых колонок
df.fillna('', inplace=True)

# Заполнение пропусков нулём для числовых колонок
df.fillna(0, inplace=True)

# %% [markdown]
# #### 4. Посмотрите внимательнее на колонку с ценой товара. Какого она типа? Создайте новую колонку так, чтобы в ней цена была числом.
#
# Для этого попробуйте применить функцию-преобразование к каждой строке вашей таблицы (для этого есть соответствующая функция).

# %%
print(df['item_price'].dtype)
df['item_price_numeric'] = df['item_price'].apply(lambda x: float(x[1:]))
# Out:
# object

# %% [markdown]
# Какая средняя/минимальная/максимальная цена у товара?

# %%
average_price = df['item_price_numeric'].mean()
min_price = df['item_price_numeric'].min()
max_price = df['item_price_numeric'].max()

print(average_price)
print(min_price)
print(max_price)
# Out:
# 7.464335785374297
# 1.09
# 44.25

# %%
Средняя цена товара: 7.464335785374297 ,Минимальная цена товара: 1.09,Максимальная цена товара: 44.25

# %% [markdown]
# Удалите старую колонку с ценой.

# %%
df.drop('item_price', axis=1, inplace=True)

# %% [markdown]
# #### 5. Какие 5 товаров были самыми дешёвыми и самыми дорогими? (по item_name)
#
# Для этого будет удобно избавиться от дубликатов и отсортировать товары. Не забудьте про количество товара.

# %%
# Создание нового столбца total_price
df['total_price'] = df['item_price_numeric'] * df['quantity']

# Группировка данных и расчёт средней цены за единицу товара и суммы проданных товаров
grouped = df.groupby('item_name').agg({'item_price_numeric': 'mean', 'quantity': 'sum', 'total_price': 'sum'})

# Сортировка данных по total_price
sorted_df = grouped.sort_values(by='total_price')

# Нахождение 5 самых дешевых и самых дорогих товаров
cheapest_items = sorted_df.head(5)
most_expensive_items = sorted_df.tail(5)

print("Самые дешевые товары:")
print(cheapest_items)

print("\nСамые дорогие товары:")
print(most_expensive_items)
# Out:
# Самые дешевые товары:
#                                    item_price_numeric  quantity  total_price
# item_name
# Chips and Mild Fresh Tomato Salsa                3.00         1         3.00
# Veggie Crispy Tacos                              8.49         1         8.49
# Carnitas Salad                                   8.99         1         8.99
# Crispy Tacos                                     7.40         2        14.80
# Salad                                            7.40         2        14.80
#
# Самые дорогие товары:
#                      item_price_numeric  quantity  total_price
# item_name
# Chips and Guacamole            4.595073       506      2475.62
# Steak Bowl                    10.711801       221      2479.81
# Steak Burrito                 10.465842       386      4236.13
# Chicken Burrito               10.082857       591      6387.06
# Chicken Bowl                  10.113953       761      8044.63

# %% [markdown]
# #### 6. Сколько раз клиенты покупали больше 1 Chicken Bowl (item_name)?

# %%
# Отфильтровать данные по item_name = "Chicken Bowl"
chicken_bowl_orders = df[df['item_name'] == 'Chicken Bowl']

# Сгруппировать данные по уникальным заказам или клиентам и подсчитать количество заказов, где Chicken Bowl больше 1
multiple_chicken_bowl_orders = chicken_bowl_orders[chicken_bowl_orders['quantity'] > 1]
total_multiple_orders = len(multiple_chicken_bowl_orders)

print(f"Клиенты покупали больше 1 Chicken Bowl {total_multiple_orders} раз(а).")
# Out:
# Клиенты покупали больше 1 Chicken Bowl 33 раз(а).

# %% [markdown]
# #### 7. Какой средний чек у заказа? Сколько в среднем товаров покупают?
#
# Если необходимо провести вычисления в терминах заказов, то будет удобно сгруппировать строки по заказам и посчитать необходимые статистики.

# %%
# Сгруппировать данные по уникальным заказам
orders_grouped = df.groupby('order_id')

# Посчитать сумму всех товаров в каждом заказе и количество уникальных товаров
order_totals = orders_grouped['total_price'].sum()
order_item_counts = orders_grouped['quantity'].sum()

# Вычислить средний чек и среднее количество товаров
average_order_total = order_totals.mean()
average_item_count = order_item_counts.mean()

print(f"Средний чек у заказа: ${average_order_total:.2f}")
print(f"В среднем товаров покупают: {average_item_count:.2f}")
# Out:
# Средний чек у заказа: $21.39
# В среднем товаров покупают: 2.71

# %% [markdown]
# #### 8. Сколько заказов содержали ровно 1 товар?

# %%
orders_with_one_item = df[df['quantity'] == 1]['order_id'].nunique()
print(f"Количество заказов с одним товаром: {orders_with_one_item}")
# Out:
# Количество заказов с одним товаром: 1760

# %% [markdown]
# #### 9. Какая самая популярная категория товара?

# %%
most_popular_category = df['choice_description'].mode()[0]
print(f"Самая популярная категория товара: {most_popular_category}")
# Out:
# Самая популярная категория товара: [Diet Coke]

# %% [markdown]
# #### 10. Какие виды Burrito существуют? Какой из них чаще всего покупают? Какой из них самый дорогой?

# %%
burrito_types = df[df['item_name'].str.contains('Burrito', case=False)]['item_name'].unique()
most_ordered_burrito = df[df['item_name'].str.contains('Burrito', case=False)]['item_name'].mode()[0]
most_expensive_burrito = df[df['item_name'].str.contains('Burrito', case=False)].groupby('total_price')['total_price'].max().idxmax()

print(f"Виды Burrito: {', '.join(burrito_types)}")
print(f"Чаще всего покупают Burrito: {most_ordered_burrito}")
print(f"Самый дорогой Burrito: {most_expensive_burrito}")
# Out:
# Виды Burrito: Steak Burrito, Chicken Burrito, Barbacoa Burrito, Carnitas Burrito, Veggie Burrito, Burrito
# Чаще всего покупают Burrito: Chicken Burrito
# Самый дорогой Burrito: 140.0

# %% [markdown]
# #### 11. В каком количестве заказов есть товар, который стоит более 40% от суммы всего чека?
#
# Возможно, будет удобно посчитать отдельно среднюю стоимость заказа, добавить ее в исходные данные и сделать необходимые проверки.
#
# *Данный комментарий стоит воспринимать как подсказку к одному из вариантов решений задания. Если в вашем варианте решения он не нужнен, это не страшно*

# %%
df['item_total'] = df['quantity'] * df['total_price']
average_order_total = order_totals.mean()
orders_with_expensive_item = df[df['total_price'] > 0.4 * df.groupby('order_id')['item_total'].transform('sum')]['order_id'].nunique()

print(f"Количество заказов с товаром, стоимость которого более 40% от суммы чека: {orders_with_expensive_item}")
# Out:
# Количество заказов с товаром, стоимость которого более 40% от суммы чека: 1556

# %% [markdown]
# #### 12. Предположим, что в данных была ошибка и Diet Coke (choice_description), который стоил $1.25, должен был стоить 1.35. Скорректируйте данные в таблицы и посчитайте, на какой процент больше денег было заработано с этого товара. Не забывайте, что количество товара не всегда равно 1.

# %%
# Исправляем цену для товара "Diet Coke"
total_revenue_before = (df['quantity'] * df['total_price']).sum()
df.loc[(df['item_name'] == 'Diet Coke') & (df['choice_description'] == '[Diet Coke]'), 'total_price'] = 1.35

# Рассчитываем общую выручку до и после изменения цены для товара "Diet Coke"
total_revenue_after = (df['quantity'] * df['total_price']).sum()

# Рассчитываем процент увеличения выручки
percent_increase = ((total_revenue_after - total_revenue_before) / total_revenue_before) * 100

print(f"Процент увеличения выручки: {percent_increase:.10f}%")
# Out:
# Процент увеличения выручки: 0.0000000000%

# %% [markdown]
# #### 13. Создайте новый DateFrame из матрицы, созданной ниже. Назовите колонки index, column1, column2 и сделайте первую колонку индексом.

# %%
import pandas as pd

data = [
    [1, 'A', 'X'],
    [2, 'B', 'Y'],
    [3, 'C', 'Z']
]

new_df = pd.DataFrame(data, columns=['index', 'column1', 'column2'])
new_df.set_index('index', inplace=True)

print(new_df)
# Out:
#       column1 column2
# index
# 1           A       X
# 2           B       Y
# 3           C       Z

# %%
Не очень понял какую матрицу нужно использовать поэтому впишу эту.set_index - метод который позволил из колонки indrx сделать индекс

# %% [markdown]
# Сохраните DataFrame на диск в формате csv без индексов и названий столбцов.

# %%
new_df.to_csv('new_data.csv', index=False, header=False)

# %% [markdown]
# ## 2. Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. В этом разделе мы этим и займёмся.
#
# У matplotlib, конечно, же есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторое величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить каждый из них. Не менее важно усвоить базовые принципы визуализаций:
# - на графиках должны быть подписаны оси;
# - у визуализации должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах).
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать.

# %%
# %matplotlib inline  # нужно для отображения графиков внутри ноутбука
import matplotlib.pyplot as plt
# Out:
# UsageError: unrecognized arguments: # нужно для отображения графиков внутри ноутбука

# %% [markdown]
# На самом деле мы уже импортировали matplotlib внутри %pylab inline в начале задания.
#
# Работать мы будем с той же выборкой покупкок. Добавим новую колонку с датой покупки.

# %%
import datetime

start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2018, 1, 31)
delta_seconds = int((end - start).total_seconds())

dates = pd.DataFrame(index=df.order_id.unique())
dates['date'] = [
    (start + datetime.timedelta(seconds=random.randint(0, delta_seconds))).strftime('%Y-%m-%d')
    for _ in range(df.order_id.nunique())]

# если DataFrame с покупками из прошлого заказа называется не df, замените на ваше название ниже
df['date'] = df.order_id.map(dates['date'])

# %% [markdown]
# #### 14. Постройте гистограмму распределения сумм покупок и гистограмму средних цен отдельных видов продуктов item_name.
#
# Изображайте на двух соседних графиках. Для этого может быть полезен subplot.

# %%
import matplotlib.pyplot as plt

order_total = df.groupby('order_id')['total_price'].sum()
plt.figure(figsize=(12, 6))
plt.hist(order_total, bins=20, color='skyblue', edgecolor='black')
plt.title('Распределение сумм покупок')
plt.xlabel('Сумма покупки ($)')
plt.ylabel('Количество заказов')
plt.grid(axis='y', alpha=0.75)
plt.show()

# Гистограмма средних цен отдельных видов продуктов item_name
plt.figure(figsize=(12, 6))
order= df.groupby('item_name')['total_price'].mean()
plt.hist(order, bins=20, color='lightcoral')
plt.xticks(rotation=90)
plt.title('Средняя цена товаров по item_name')
plt.xlabel('Наименование товара')
plt.ylabel('Средняя цена ($)')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
Может у меня что-то не получилось в гистограме, но стлобцами лучше

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['item_name'].unique(), df.groupby('item_name')['total_price'].mean(), color='lightcoral')
plt.xticks(rotation=90)
plt.title('Средняя цена товаров по item_name')
plt.xlabel('Наименование товара')
plt.ylabel('Средняя цена ($)')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# #### 15. Постройте график зависимости суммы покупок от дней.

# %%
# Преобразуем столбец 'order_date' к типу datetime
df['date'] = pd.to_datetime(df['date'])

# График зависимости суммы покупок от дней
daily_total = df.groupby('date')['total_price'].sum()
plt.figure(figsize=(12, 6))
plt.plot(daily_total.index, daily_total.values, marker='o', color='orange')
plt.title('Зависимость суммы покупок от дней')
plt.xlabel('Дата')
plt.ylabel('Сумма покупки ($)')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# #### 16. Постройте средних сумм покупок по дням недели (bar plot).

# %%
# Добавим столбец с днем недели
df['day_of_week'] = df['date'].dt.dayofweek

# Средние суммы покупок по дням недели
daily_avg_total = df.groupby('day_of_week')['total_price'].mean()
days = ['Пн', 'Вт', 'Ср', 'Чт', 'Пт', 'Сб', 'Вс']
plt.figure(figsize=(10, 6))
plt.bar(days, daily_avg_total, color='lightgreen')
plt.title('Средние суммы покупок по дням недели')
plt.xlabel('День недели')
plt.ylabel('Средняя сумма покупки ($)')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# #### 17. Постройте график зависимости денег за товар от купленного количества (scatter plot).

# %%
# График зависимости денег за товар от купленного количества
plt.figure(figsize=(10, 6))
plt.scatter(df['quantity'], df['total_price'], color='purple', alpha=0.5)
plt.title('Зависимость денег за товар от купленного количества')
plt.xlabel('Количество товаров')
plt.ylabel('Цена товара ($)')
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# #### 18. Сохраните график в формате pdf (так он останется векторизованным).

# %%
plt.savefig('my_plot.pdf', format='pdf')

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
